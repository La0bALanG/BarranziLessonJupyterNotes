# %%
# !pip install seaborn bokeh
# Out:
# Looking in indexes: http://repo.myhuaweicloud.com/repository/pypi/simple
# Collecting seaborn
#   Downloading http://repo.myhuaweicloud.com/repository/pypi/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 18.2 MB/s eta 0:00:00
# Collecting bokeh
#   Downloading http://repo.myhuaweicloud.com/repository/pypi/packages/1a/02/b312d65b83d0ec17d73e1594118e1163a4d79546925424374922fab2ea09/bokeh-3.4.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 41.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=1.2 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from seaborn) (1.5.1)
# Collecting matplotlib!=3.6.1,>=3.4
#   Downloading http://repo.myhuaweicloud.com/repository/pypi/packages/d3/6d/45837c5b3d0005a5a9b04729b218a16bf3aa195701c6b33b2cc39ae943b6/matplotlib-3.9.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 128.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML>=3.10 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from bokeh) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from bokeh) (3.0.1)
# Requirement already satisfied: pillow>=7.1.0 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from bokeh) (9.3.0)
# Collecting contourpy>=1.2
#   Downloading http://repo.myhuaweicloud.com/repository/pypi/packages/31/a2/2f12e3a6e45935ff694654b710961b03310b0e1ec997ee9f416d3c873f87/contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.0/305.0 KB 15.2 MB/s eta 0:00:00
# Collecting xyzservices>=2021.09.1
#   Downloading http://repo.myhuaweicloud.com/repository/pypi/packages/b7/2c/08768a39947864fcebc19f059b758d8169a2ac183a61361359f56c144f7c/xyzservices-2024.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.2 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from bokeh) (6.3.2)
# Requirement already satisfied: packaging>=16.8 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from bokeh) (23.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh) (2.1.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Collecting importlib-resources>=3.2.0
#   Downloading http://repo.myhuaweicloud.com/repository/pypi/packages/75/06/4df55e1b7b112d183f65db9503bff189e97179b256e1ea450a3c365241e0/importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: cycler>=0.10 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.16.2)
# Requirement already satisfied: six>=1.5 in /home/ma-user/anaconda3/envs/PyTorch-2.0.0/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: xyzservices, importlib-resources, contourpy, matplotlib, seaborn, bokeh
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.1.0
#     Uninstalling contourpy-1.1.0:
#       Successfully uninstalled contourpy-1.1.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.1
#     Uninstalling matplotlib-3.6.1:
#       Successfully uninstalled matplotlib-3.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# modelarts 1.4.20 requires matplotlib==3.5.2, but you have matplotlib 3.9.0 which is incompatible.
# modelarts 1.4.20 requires networkx==2.6.3, but you have networkx 3.1 which is incompatible.
# modelarts 1.4.20 requires typing-extensions<=4.0.1, but you have typing-extensions 4.6.3 which is incompatible.
# ma-cau 1.1.7 requires click==8.1.3, but you have click 8.1.6 which is incompatible.
# ma-cau 1.1.7 requires huaweicloudsdkcore==3.1.8, but you have huaweicloudsdkcore 3.1.96 which is incompatible.
# ma-cau 1.1.7 requires matplotlib==3.5.1, but you have matplotlib 3.9.0 which is incompatible.
# ma-cau 1.1.7 requires numpy<=1.22.1, but you have numpy 1.24.2 which is incompatible.
# ma-cau 1.1.7 requires pandas<=1.3.5, but you have pandas 1.5.1 which is incompatible.
# ma-cau 1.1.7 requires Pillow==9.5.0, but you have pillow 9.3.0 which is incompatible.
# ma-cau 1.1.7 requires tenacity<=8.2.2, but you have tenacity 8.2.3 which is incompatible.
# ma-cau 1.1.7 requires typing-extensions<=4.0.1, but you have typing-extensions 4.6.3 which is incompatible.
# Successfully installed bokeh-3.4.1 contourpy-1.2.1 importlib-resources-6.4.0 matplotlib-3.9.0 seaborn-0.13.2 xyzservices-2024.4.0
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/home/ma-user/anaconda3/envs/PyTorch-2.0.0/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# 设置单元格所有行全部输出模式
from IPython.core.interactiveshell import InteractiveShell

# 设置InteractiveShell对象的ast_node_interactivity的值为all，即表示每一个单元格所有有输出的代码行全部需要输出
InteractiveShell.ast_node_interactivity = 'all'

# 设置全局随机种子
np.random.seed(sum(map(ord, "aesthetics")))

# %matplotlib inline

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
sns.set_style("darkgrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
sns.set_style("dark")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
sns.set_style("white")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data)
# Out:
# <Axes: >
