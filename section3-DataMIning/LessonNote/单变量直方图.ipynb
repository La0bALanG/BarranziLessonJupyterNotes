# %%
# !pip install seaborn bokeh

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns

# 设置单元格所有行全部输出模式
from IPython.core.interactiveshell import InteractiveShell

# 设置InteractiveShell对象的ast_node_interactivity的值为all，即表示每一个单元格所有有输出的代码行全部需要输出
InteractiveShell.ast_node_interactivity = 'all'

sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))
# %matplotlib inline

# %%
x = np.random.normal(size=100)
sns.distplot(x, kde=False, rug=True) # kde=False绘制直方图，rug=True为每个观察值添加一个tick
# Out:
# /tmp/ipykernel_11568/3961568143.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, kde=False, rug=True) # kde=False绘制直方图，rug=True为每个观察值添加一个tick
# <Axes: >

# %%
sns.distplot(x, kde=False, hist=False, rug=True) # 绘制rugplot，有单独的sns.rugplot()函数
# Out:
# /tmp/ipykernel_11568/450974989.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, kde=False, hist=False, rug=True) # 绘制rugplot，有单独的sns.rugplot()函数
# <Axes: >

# %%
sns.distplot(x, bins=20, kde=False, rug=True) # bins参数，设置bin的个数
# Out:
# /tmp/ipykernel_11568/3007872118.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, bins=20, kde=False, rug=True) # bins参数，设置bin的个数
# <Axes: >
